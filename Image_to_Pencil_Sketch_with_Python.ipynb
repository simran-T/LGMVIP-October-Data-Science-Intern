# %% [markdown]
# <a href="https://colab.research.google.com/github/simran-T/LGMVIP-October-Data-Science-Intern/blob/main/Image_to_Pencil_Sketch_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Name : Simran T
# # Data Science Intern at LetsGrowMore (VIP)
# # Beginner Level Task 4 - Image to Pencil Sketch with Python

# %% [markdown]
# # Importing Libraries

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
path = '/content/stevejobs.jfif'
img = cv2.imread(path)
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=276x182 at 0x7FE0153573D0>

# %% [markdown]
# # Converting to Grey image

# %%
grey_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(grey_img)
# Out:
# <PIL.Image.Image image mode=L size=276x182 at 0x7FE0077BE990>

# %% [markdown]
# # Invert image

# %%
invert_img = cv2.bitwise_not(grey_img)
cv2_imshow(invert_img)
# Out:
# <PIL.Image.Image image mode=L size=276x182 at 0x7FE0077CD290>

# %% [markdown]
# # Blur image

# %%
k_size = 7
blur_img = cv2.GaussianBlur(invert_img, (k_size,k_size),0)
cv2_imshow(blur_img)
# Out:
# <PIL.Image.Image image mode=L size=276x182 at 0x7FE0077CDD50>

# %% [markdown]
# # Inverted Blurred image

# %%
invblur_img = cv2.bitwise_not(blur_img)
cv2_imshow(invblur_img)
# Out:
# <PIL.Image.Image image mode=L size=276x182 at 0x7FE0077D4490>

# %% [markdown]
# # Sketch image

# %%
sketch_img = cv2.divide(grey_img,invblur_img, scale=256.0)
cv2_imshow(sketch_img)
# Out:
# <PIL.Image.Image image mode=L size=276x182 at 0x7FE0077D4910>
